# %% [markdown]
# # https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/course-zoomcamp/01-intro/homework.md

# %%
import numpy as np
import pandas

# %%
print(np.__version__)
# Out:
# 1.19.5

# %%
print(pandas.__version__)
# Out:
# 1.3.2

# %%
data = pandas.read_csv("data/car-price-data.csv")

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data["MSRP"].mean()
# Out:
# 40594.737032063116

# %%
data_bmw = data[data.Make=="BMW"]

# %%
data_bmw.shape
# Out:
# (334, 16)

# %%
data_bmw
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
data_bmw.MSRP.mean()
# Out:
# 61546.76347305389

# %%
data_f2015 = data[data.Year>=2015]

# %%
data_f2015
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
data_f2015['Engine HP'].isnull().sum()  #51
# Out:
# 51

# %%
avg = data_f2015['Engine HP'].mean() # 272.98771870794076

# %%
data_f2015['Engine HP'] = data_f2015['Engine HP'].fillna(avg)

# %%
avg2 = data_f2015['Engine HP'].mean()

# %%
print(round(avg))
print(round(avg2))
# Out:
# 273
# 273

# %%
data_rollsroyce = data[data.Make=="Rolls-Royce"]

# %%
data_rollsroyce.Make.count()
# Out:
# 31

# %%
data_rr3 = data_rollsroyce[["Engine HP", "Engine Cylinders", "highway MPG"]]

# %%
data_rr3
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5276       563.0              12.0           21
# 5277       563.0              12.0           21
# 5278       563.0              12.0           21
# 5279       563.0              12.0           20
# 5280       563.0              12.0           20
# 5281       563.0              12.0           21
# 5282       563.0              12.0           21
# 5283       563.0              12.0           21
# 5284       563.0              12.0           21
# 7443       322.0              12.0           15
# 7444       322.0              12.0           15
# 7553       453.0              12.0           19
# 7554       453.0              12.0           19
# 7555       453.0              12.0           19
# 7556       453.0              12.0           19
# 7557       453.0              12.0           19
# ...

# %%
data_rr3x = data_rr3.drop_duplicates()

# %%
data_rr3x
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X = data_rr3x.to_numpy()

# %%
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
XTX = np.dot(X.T,X)

# %%
XTX
# Out:
# array([[1.754801e+06, 3.965600e+04, 6.519600e+04],
#        [3.965600e+04, 9.280000e+02, 1.500000e+03],
#        [6.519600e+04, 1.500000e+03, 2.454000e+03]])

# %%
XTXinv = np.linalg.inv(XTX)

# %%
XTXinv
# Out:
# array([[ 5.17815728e-05,  9.06587044e-04, -1.92984188e-03],
#        [ 9.06587044e-04,  1.05723058e-01, -8.87084092e-02],
#        [-1.92984188e-03, -8.87084092e-02,  1.05900809e-01]])

# %%
np.sum(XTXinv)
# Out:
# 0.032212320677486125

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
y
# Out:
# array([1000, 1100,  900, 1200, 1000,  850, 1300])

# %%
X2 = np.dot(XTXinv,X.T)

# %%
X2
# Out:
# array([[-0.00486592,  0.00336507, -0.00049461,  0.00143523, -0.00139492,
#         -0.0023309 ,  0.00266407],
#        [-0.19020088,  0.09362543, -0.08379139,  0.00491702,  0.22997159,
#         -0.00609915, -0.02848958],
#        [ 0.25164625, -0.13888652,  0.0729151 , -0.03298571, -0.09739786,
#          0.07339609, -0.04480526]])

# %%
w = np.dot(X2,y)

# %%
w  # 0.19989598
# Out:
# array([ 0.19989598, 31.02612262, 31.65378877])
